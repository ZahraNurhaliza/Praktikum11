# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://www.bukalapak.com/c/komputer/laptop?from=nav_header"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
produk = soup.find_all("div", "bl-product-card__description")

data = []
for item in produk:
  nama = item.select(".bl-product-card__description-name")
  price = item.select(".bl-product-card__description-price p")
  data.append({"nama": nama[0].text.strip(), "harga": price[0].text.strip()})
  
#print(data)
df = pd.DataFrame(data)
print(df)
# Out:
#                                                  nama        harga
# 0   pc817 pc 817 optocoupler sharp asli ori origin...        Rp500
# 1   OTG kabel usb micro kabel otg for samsung bb o...      Rp2.500
# 2   Kabel power Komputer Pc ups rice cooker lcd ka...     Rp10.000
# 3   KABEL POWER CPU PC KOMPUTER MONITOR KE LISTRIK...     Rp30.000
# 4   Kabel Splitter Audio 3.5mm Male to 3.5mm HiFi ...      Rp7.500
# 5   Laptop Dell Latitude 5480 Core i5 7440HQ NVIDI...  Rp7.150.000
# 6   Laptop Lenovo Thinkpad T460s Core i5 6300U US ...  Rp6.030.000
# 7   Laptop Dell E5450 Core i5 5300u Ex USA - Origi...  Rp3.890.000
# 8   Laptop Lenovo Thinkpad X260 Core i5 6300U US K...  Rp3.680.000
# 9   Laptop Dell Latitude 7480 Core i7 6600U M2 - O...  Rp6.030.000
# 10  Laptop Lenovo Thinkpad X260 Core i5 6300U Dual...  Rp4.860.000
# 11  Laptop HP Elitebook 820 G3 Core i7 6600U Win 1...  Rp6.030.000
# 12  Laptop HP Elitebook 840 G6 Core i5 8265U Win 1...  Rp8.380.000
# 13  Laptop HP Elitebook X360 1030 G2 Core i7 7600U...  Rp8.280.000
# 14  Laptop Lenovo Thinkpad T470 Core i5 US KEYBOAR...  Rp6.130.000
# 15  Laptop Lenovo Thinkpad T450 Core i5 5300U US K...  Rp3.680.000
# 16  Laptop Dell Latitude 5490 Core i7 8650U SSD M2...  Rp7.670.000
# 17  Laptop HP Elitebook 840 G5 Core i5 8350U  - Or...  Rp8.180.000
# 18  Laptop Lenovo Thinkpad T460 Core i5 6300U US K...  Rp4.600.000
# 19               Laptop Hp 8440p Core i5 Sedang promo  Rp2.099.000
# 20  Laptop HP Elitebook 840 G6 Core i7 8565U Win 1...  Rp9.200.000
# 21  Kabel MHL Converter Micro USB to HDMI Kabel fo...     Rp50.000
# 22  Laptop Lenovo Thinkpad T460s Core i7 6600U US ...  Rp7.150.000
# 23  Baterai Toshiba Satellite C600 C640 C666 L635 ...    Rp450.000
# 24                   Kabel Aux Audio 2in1 For Speaker      Rp5.000
# 25  Laptop Lenovo P50 + Numeric Tombol core i7 - S...  Rp8.700.000
# 26  MacBook Air 2017 Core i5 13.3 inch Intel HD Gr...  Rp7.421.000
# 27  Baterai Asus X450 X450C X450CA X450CP X450V X4...    Rp189.000
# 28  Baterai Asus A46 A46C A46CA A46CB A46CM A46 K4...    Rp189.000
# 29  Baterai Ori Acer v5 V5-431 V5-431G V5-471 V5-4...    Rp184.500
